# %%
import pandas as pd
import ast

# %% [markdown]
# ### Nettoyage Résultats

# %%
results = pd.read_html('imports/olympic_results.html', index_col=0, encoding='utf-8')[0]
results.head()
# Out:
#   discipline_title    event_title     slug_game participant_type medal_type  \
# 0          Curling  Mixed Doubles  beijing-2022         GameTeam       GOLD
# 1          Curling  Mixed Doubles  beijing-2022         GameTeam     SILVER
# 2          Curling  Mixed Doubles  beijing-2022         GameTeam     BRONZE
# 3          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 4          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
#
#                                             athletes rank_equal rank_position  \
# 0  [('Stefania CONSTANTINI', 'https://olympics.co...      False             1
# 1  [('Kristin SKASLIEN', 'https://olympics.com/en...      False             2
# 2  [('Almida DE VAL', 'https://olympics.com/en/at...      False             3
# 3  [('Jennifer DODDS', 'https://olympics.com/en/a...      False             4
# 4  [('Rachel HOMAN', 'https://olympics.com/en/ath...      False             5
#
#     country_name country_code country_3_letter_code athlete_url  \
# 0          Italy           IT                   ITA         NaN
# 1         Norway           NO                   NOR         NaN
# 2         Sweden           SE                   SWE         NaN
# 3  Great Britain           GB                   GBR         NaN
# 4         Canada           CA                   CAN         NaN
#
#   athlete_full_name value_unit value_type
# 0               NaN        NaN        NaN
# 1               NaN        NaN        NaN
# 2               NaN        NaN        NaN
# 3               NaN        NaN        NaN
# 4               NaN        NaN        NaN

# %%
# informations des colonnes
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162804 entries, 0 to 162803
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   discipline_title       162804 non-null  object
#  1   event_title            162804 non-null  object
#  2   slug_game              162804 non-null  object
#  3   participant_type       162804 non-null  object
#  4   medal_type             20206 non-null   object
#  5   athletes               7976 non-null    object
#  6   rank_equal             32526 non-null   object
#  7   rank_position          158926 non-null  object
#  8   country_name           162804 non-null  object
#  9   country_code           157768 non-null  object
#  10  country_3_letter_code  162804 non-null  object
#  11  athlete_url            129991 non-null  object
#  12  athlete_full_name      141646 non-null  object
#  13  value_unit             78646 non-null   object
#  14  value_type             90049 non-null   object
# dtypes: object(15)
# memory usage: 19.9+ MB

# %%
# dimensions
results.shape
# Out:
# (162804, 15)

# %%
def explode_athletes(row: pd.Series) -> list:
    '''
    Duplique une ligne du DataFrame en fonction du nombre d'athlètes
    '''
    athletes = row['athletes']
    if pd.isna(athletes) or athletes == '[]':
        return [row]
    
    athletes = ast.literal_eval(athletes)
    new_rows = []
    for athlete in athletes:
        new_row = row.copy()
        new_row['athlete_full_name'] = athlete[0]
        new_row['athlete_url'] = athlete[1]
        new_rows.append(new_row)
    return new_rows

# %%
# applatir les lignes selon les athlètes
expanded_rows = []
for index, row in results.iterrows():
    expanded_rows.extend(explode_athletes(row))

# %%
cleaned_results = pd.DataFrame(expanded_rows)

# %%
# suppression de la colonne athletes
cleaned_results.drop(columns=['athletes', 'medal_type'], inplace=True)

# %%
# dimensions
cleaned_results.shape
# Out:
# (170780, 13)

# %%
# vérifier les doublons
cleaned_results.duplicated().sum()
# Out:
# 144

# %%
# supprimer les doublons
cleaned_results.drop_duplicates(inplace=True)

# %%
# dimensions
cleaned_results.shape
# Out:
# (170636, 13)

# %%
# on vérifie les valeurs uniques de la colonne 'value_type'
cleaned_results['value_type'].unique()
# Out:
# array([nan, 'POINTS', 'SC_REST$IRM', 'IRM', 'CODE', 'TIME', 'NO_TIME',
#        'IRM_POINTS', 'STROKES', 'WEIGHT', 'DISTANCE', 'RANK', 'SCORE'],
#       dtype=object)

# %%
# supprimer les value_type associés à des valeurs nulles
for value_type in cleaned_results['value_type'].unique():
    value_type_rows = cleaned_results[cleaned_results['value_type'] == value_type]
    if value_type_rows['value_unit'].isna().all():
        cleaned_results.loc[cleaned_results['value_type'] == value_type, 'value_type'] = None

# %%
# voir les lignes dont value_type est manquante et la valeur de value_unit est renseignée
cleaned_results[cleaned_results['value_type'].isna() & cleaned_results['value_unit'].notna()][0:5]
# Out:
#      discipline_title         event_title     slug_game participant_type  \
# 3364    Speed skating  Women's Mass Start  beijing-2022          Athlete
# 3369    Speed skating  Women's Mass Start  beijing-2022          Athlete
# 3370    Speed skating  Women's Mass Start  beijing-2022          Athlete
# 3375    Speed skating  Women's Mass Start  beijing-2022          Athlete
# 3376    Speed skating  Women's Mass Start  beijing-2022          Athlete
#
#      rank_equal rank_position       country_name country_code  \
# 3364      False            11        Netherlands           NL
# 3369      False             8              Japan           JP
# 3370      False            26  Republic of Korea           KR
# 3375      False            15                ROC          ROC
# 3376      False             7            Belarus           BY
#
#      country_3_letter_code                                        athlete_url  \
# 3364                   NED  https://olympics.com/en/athletes/marijke-groen...
# 3369                   JPN        https://olympics.com/en/athletes/ayano-sato
# 3370                   KOR       https://olympics.com/en/athletes/ji-woo-park
# 3375                   ROC  https://olympics.com/en/athletes/elizaveta-gol...
# 3376                   BLR     https://olympics.com/en/athletes/maryna-zuyeva
#
#        athlete_full_name value_unit value_type
# 3364  Marijke GROENEWOUD      27.46        NaN
# 3369          Ayano SATO      33.88        NaN
# 3370         Ji Woo PARK      33.70        NaN
# 3375  Elizaveta GOLUBEVA      27.81        NaN
# 3376       Maryna ZUYEVA      45.47        NaN

# %%
# il s'agit d'un chrono donc on crée une nouvelle valeur pour value_type
cleaned_results.loc[cleaned_results['value_type'].isna() & cleaned_results['value_unit'].notna(), 'value_type'] = 'CHRONO'

# %%
# maintenant l'inverse, voir les lignes dont value_type est renseignée et value_unit est manquante
cleaned_results.loc[cleaned_results['value_type'].notna() & cleaned_results['value_unit'].isna()][0:5]
# Out:
#       discipline_title                        event_title   slug_game  \
# 10267           Rowing  Lightweight Women's Double Sculls  tokyo-2020
# 10267           Rowing  Lightweight Women's Double Sculls  tokyo-2020
# 10268           Rowing  Lightweight Women's Double Sculls  tokyo-2020
# 10268           Rowing  Lightweight Women's Double Sculls  tokyo-2020
# 10269           Rowing  Lightweight Women's Double Sculls  tokyo-2020
#
#       participant_type rank_equal rank_position country_name country_code  \
# 10267         GameTeam      False             1        Italy           IT
# 10267         GameTeam      False             1        Italy           IT
# 10268         GameTeam      False             2       France           FR
# 10268         GameTeam      False             2       France           FR
# 10269         GameTeam      False             3  Netherlands           NL
#
#       country_3_letter_code  \
# 10267                   ITA
# 10267                   ITA
# 10268                   FRA
# 10268                   FRA
# 10269                   NED
#
#                                              athlete_url  athlete_full_name  \
# 10267  https://olympics.com/en/athletes/valentina-rodini   Valentina RODINI
# 10267  https://olympics.com/en/athletes/federica-cesa...  Federica CESARINI
# 10268   https://olympics.com/en/athletes/laura-tarantola    Laura TARANTOLA
# 10268       https://olympics.com/en/athletes/claire-bove        Claire BOVE
# 10269   https://olympics.com/en/athletes/marieke-keijser    Marieke KEIJSER
#
#       value_unit value_type
# 10267        NaN       TIME
# 10267        NaN       TIME
# 10268        NaN       TIME
# 10268        NaN       TIME
# 10269        NaN       TIME

# %%
# ces valeurs sont inutilisables, on les remplace par des NaN
cleaned_results.loc[cleaned_results['value_type'].notna() & cleaned_results['value_unit'].isna(), 'value_type'] = None

# %%
# valeurs manquantes
cleaned_results.isna().sum()
# Out:
# discipline_title              0
# event_title                   0
# slug_game                     0
# participant_type              0
# rank_equal               137300
# rank_position              3879
# country_name                  0
# country_code               5238
# country_3_letter_code         0
# athlete_url               25586
# athlete_full_name         13155
# value_unit                87841
# value_type                87841
# dtype: int64

# %%
# exportation
cleaned_results.to_csv('exports/olympic_results_cleaned.csv', index=False , encoding='utf-8')

# %% [markdown]
# ### Nettoyage Athlètes

# %%
athletes = pd.read_json('imports/olympic_athletes.json', encoding='utf-8')
athletes.head()
# Out:
#                                          athlete_url       athlete_full_name  \
# 0  https://olympics.com/en/athletes/cooper-woods-...  Cooper WOODS-TOPALOVIC
# 1          https://olympics.com/en/athletes/elofsson          Felix ELOFSSON
# 2     https://olympics.com/en/athletes/dylan-walczyk           Dylan WALCZYK
# 3     https://olympics.com/en/athletes/olli-penttala           Olli PENTTALA
# 4          https://olympics.com/en/athletes/reikherd        Dmitriy REIKHERD
#
#    games_participations        first_game  athlete_year_birth athlete_medals  \
# 0                     1      Beijing 2022              2000.0           None
# 1                     2  PyeongChang 2018              1995.0           None
# 2                     1      Beijing 2022              1993.0           None
# 3                     1      Beijing 2022              1995.0           None
# 4                     1      Beijing 2022              1989.0           None
#
#     bio
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
# informations des colonnes
athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75904 entries, 0 to 75903
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   athlete_url           75904 non-null  object
#  1   athlete_full_name     75904 non-null  object
#  2   games_participations  75904 non-null  int64
#  3   first_game            75882 non-null  object
#  4   athlete_year_birth    73448 non-null  float64
#  5   athlete_medals        15352 non-null  object
#  6   bio                   22842 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 4.1+ MB

# %%
# vérifier les doublons
athletes.duplicated().sum()
# Out:
# 0

# %%
# vérifier les valeurs manquantes
athletes['athlete_year_birth'].isna().sum()
# Out:
# 2456

# %%
# remplacer les valeurs nulles par 0
athletes.fillna({ 'athlete_year_birth': 0 }, inplace=True)

# %%
# convertir l'année de naissance en entier
athletes['athlete_year_birth'] = athletes['athlete_year_birth'].astype(int)

# %%
# vérifier le type des dates de naissance
athletes['athlete_year_birth'].dtype
# Out:
# dtype('int64')

# %%
# vérifier les valeurs nulles
athletes.isna().sum()
# Out:
# athlete_url                 0
# athlete_full_name           0
# games_participations        0
# first_game                 22
# athlete_year_birth          0
# athlete_medals          60552
# bio                     53062
# dtype: int64

# %%
# nettoyer les biographies
athletes['bio'] = athletes['bio'].str.strip().replace('\n', ' ')

# %%
# formater le nombre de médailles
athletes['athlete_medals'] = athletes['athlete_medals'].replace('\n', '')

# %%
# en prévision de l'insertion en bdd, on vérifie les différences entre les dataframes cleaned_results et athletes
cleaned_results_athletes = cleaned_results['athlete_full_name'].unique()
athletes_athletes = athletes['athlete_full_name'].unique()

# différences
missing_athletes = set(cleaned_results_athletes) - set(athletes_athletes)
missing_athletes
# Out:
# {'Yury Zakharov',
#  'Abdel Malek El-Aouad',
#  'Bob Curry',
#  'Rubem Ribeiro',
#  'Jong-Hun Sin',
#  'George Smith',
#  'Leri Khabelovi',
#  'Rodolfo Wagner',
#  '- Viéville',
#  'Cesare Locatelli',
#  'Dimitar Galinchev',
#  'Carl Körting',
#  'Casimiro Vega',
#  'Judit Kéri-Novák',
#  'Charlie Purdy',
#  'Fazlollah Dehkhoda',
#  'Greetje Gaillard',
#  'Georgi Georgiev',
#  'Hayk Yeghiazaryan',
#  'Yelena Pavluxina',
#  'Marcel Moret',
#  'William Plant',
#  'Yanan Wu',
#  'Dmitry Bochkaryov',
#  'Bandi Damdinjavyn',
#  'Bob Maslen-Jones',
#  'Agnes Olsen',
#  'Erich Gallwitz',
#  'Ali Heidar Ali Mohamed',
#  'P. F. Koukoudakis',
#  'Freddie Meachem',
#  'Alexandros Khalkokondylis',
#  'Chung-Yeol Yang',
#  'Mohamed Al-Takroni',
#  'Josef Pavlík',
#  'Cemil Sarıbacak',
#  'John Walker',
#  'Tin Dekkers',
#  'Guðmundur Helgason',
#  'Abdul Rehman',
#  'Bob Fowler',
#  'Austin Anthony',
#  'Jean Madelaine',
#  'Edmond Filiâtre',
#  "Frank O'Neill",
#  'Harold Simpkins',
#  'Umberto Del Carlo',
#  'Lyuben Khristov',
#  'Tarek Fouad',
#  '- Pelat',
#  'Konstantinos Loudaros',
#  'Aleksey Mishin',
#  'Rudolf Heidegger',
#  'František Havelka',
#  'Bakshish Singh',
#  'Jacob Simonis',
#  'Oscar Aas Haugen',
#  'Hennadiy Nikon',
#  'Boldbaatar Khaliuny',
#  'Émile-Georges Drigny',
#  'Antonín Siegl',
#  'Seong-Ryeol Jegal',
#  'Ned Barrett',
#  'Wijit Suksompong',
#  'Valdimar Örnólfsson',
#  'Lucien Bottin',
#  'Yevgeny Alekseyev',
#  'Joe Barbosa',
#  'Saad El-Din El-Shorbagui',
#  'Irina Krivko',
#  'Floyd Rowe',
#  "Vikt'or K'rat'asiuk'i",
#  'Aleksey Aydarov',
#  'Ragai Youssef',
#  'Mohamed Al-Kaabi',
#  'Aligri Amletto',
#  'Wen-Chia Wu',
#  'Mohamed Selim Soheim',
#  'J. Adriaenssens',
#  'Harry Blaus',
#  'Sim Price',
#  'Jamal Ahmed Al-Doseri',
#  'Erdenebat Sandagsürengiin',
#  'Chanyalew Haile',
#  'Augusto Premoli',
#  'Clarrie Gordon',
#  'Nelya Sevostiyanova',
#  'Ekrem Güçlüer',
#  'Jack King',
#  'Abdul Haji Abdul Latheef',
#  'Fabienne Etlensperger',
#  'J. A. Tynan',
#  'Kostiantyn Shkolniy',
#  'Yu Du',
#  'Hermann Müller',
#  'Aleksandr Dekhayev',
#  'Ahmed Al-Arbeed',
#  'Petro Denysenko',
#  'Aleksandr Bogdanovich',
#  'K. Salouros',
#  'Edy Paul',
#  'Irving Pease',
#  'Tetiana Shelekhova',
#  'Bryan Harper',
#  'Jack Nielsen, Jr.',
#  'Ernest McCartney',
#  'Ioannis Seraidaris',
#  'Ui-Je Mun',
#  'Salvador García',
#  'Englebert Mollin',
#  'Arthur St. Norman',
#  'Yury Klyuyev',
#  'Karl Jank',
#  'L. Lacombe',
#  'Latt Shwe Zin',
#  'Andrés Gerard, Sr.',
#  'Attila Szekrényessy',
#  'Chandgi Ram',
#  'Fatimə Alkərəmova',
#  'Mick McKeon',
#  'Abebe Mekonnen',
#  'Choji Hosaka',
#  'Eornel Kell',
#  'Ena Stockley',
#  'Percy May',
#  'Martin Jacobsen',
#  'Alphonso Correia',
#  'Jack Wardrop',
#  'Oleh Polyvach',
#  'Rasoul Khadem Azgadhi',
#  'Sumyaabazar Dolgorsürengiin',
#  'Olga Gayeva',
#  'Víctor Saucedo',
#  'Giannis Gavrilidis',
#  'Bakhtiyar Bayseitov',
#  'Vazik Ghazarian',
#  'Fred Rödiger',
#  'Erich Schnarre',
#  'Vasily Yegorov',
#  'Shamsiddin Khudoyberdiyev',
#  'Alfreð Karl Alfreðsson',
#  'Jan Plichta',
#  'Karel Pott',
#  'Nataliya Donchenko',
#  'Borislav Stoyanov',
#  'Se-Gwang Ri',
#  'Ingrid Berghmans',
#  'Nikolay Kulpin',
#  'Serhiy Holubytskiy',
#  'Abraham Mok',
#  'John Røen',
#  'Anatoliy Cherepovych',
#  'Tai-Koo Kim',
#  'Robert Reid, Sr.',
#  'Bruce Wells',
#  'Jean Chastanié',
#  'Byeong-Guk Jeon',
#  'Rəşəd Əhmədov',
#  'Teodors Sukatnieks',
#  'Vacislav Neiman',
#  'Gwang-Je Jo',
#  'Nadezhda Andreyeva-Patrikeyeva',
#  'Anna Gorchonok',
#  'Ji Li',
#  'Jean Berhouzouq',
#  'Kenneth Nelson',
#  'Katharine Connal',
#  'Trev Haynes',
#  'Sven Palle Sørensen',
#  'František Řezáč',
#  'Donald Slack',
#  'Bor Jamtsyn',
#  'Johan Heijm',
#  'Rafael Pérez',
#  'Walter Hoover, Sr.',
#  'Théo Jeitz',
#  'Altansükh Sodnomdarjaagiin',
#  'Gustave Amoly',
#  'Jorge Perry',
#  'Mimoun Ouitot',
#  'Leendert van Oosten',
#  'Robert Eustache',
#  'Georges Dumonteuil',
#  'Ying Liu',
#  'Steve Alger',
#  'Václav Bičák',
#  'Sumol Sumontame',
#  'Mary Proença',
#  'Dikke Eger-Bergman',
#  "M'Bar N'Diaye",
#  'Dietmar Schweninger',
#  'Altantuyaa Sanjaajamtsyn',
#  'Charles Johnson',
#  'Sami Al-Baker',
#  'Amund Sjøbrend',
#  'Eric Prabhakar',
#  'A. Abdul Razzak',
#  'Dick Garrard',
#  'Charles-Jean LeVavasseur',
#  'Mustafa Osmanlı',
#  'Sergey Klimov',
#  'Les Carney',
#  '- Touche',
#  'Byambasüren Shagdaryn',
#  'Adelaide Boddam-Whetham',
#  'Aristidis Akratopoulos',
#  'Willan Bouza',
#  'Edward Beeson',
#  'Annegret Richter',
#  'Hyeon-Ju Sin',
#  'Athina Bokhori',
#  'O. Molina',
#  'D. Frangopoulos',
#  'Dušan Zinaja',
#  'Jacobus Lorenz',
#  'William Murray',
#  'Paul Fischer',
#  'Konstantin Lukashik',
#  'Albert Nuss',
#  'Georges Mauvezain',
#  'Hassan Eghmaz',
#  'Ilunga Zatara Mande',
#  'André Franquenelle',
#  'Ahmed Khalaf Ali',
#  'Jenn Stuczynski-Suhr',
#  'Petros Leonidis',
#  'Alekhis Fotiadis',
#  'Fränz Ehringer',
#  'Jack Treadaway',
#  'Marina Sysoyeva',
#  'Jacques De Wykerslooth De Rooyesteyn',
#  'Gertrudes Lozada',
#  'Gilbert Bougnol',
#  'Bob Broadbent',
#  'Zdzisław Latawiec',
#  'Bertie Heathcote',
#  'Maurice Laraigne',
#  'Kornélia Ihász',
#  'Bronislav Samoylov',
#  'Susann Sundqvist',
#  'D. Flaherty',
#  'Omar Ehrman',
#  '- Reynal',
#  'Henry Nielsen',
#  'Raymond Van Rumbecke',
#  'Peter Scott',
#  '- Chambeau',
#  '- Cabanac',
#  'Rohinton Noble',
#  'Sid Patterson',
#  'Jin-Cheol Jeon',
#  'Hae-Ri Jo',
#  'Marilyn Chua',
#  'Vicente Abad',
#  'Al Young',
#  'Sigmund Søfteland',
#  'William Crabbie',
#  'Cornelius von Lubowiecki',
#  'Berit Christoffersen',
#  'Nehemia Sirkis',
#  'Bayar Palamdorjiin',
#  'Vasil Bozhilov',
#  'Aleksey Kiselyov',
#  'Philip Schuster',
#  'Khristo Kochov',
#  'Joé Kieffer',
#  'Lkhamjav Tsedenjavyn',
#  'Bjørnar Vestøl',
#  'Wohib Masresha',
#  'Clément Roux',
#  'David Fredericks',
#  'Dmitry Matveyev',
#  'Anton Gottstein',
#  'Velichka Mincheva',
#  'Muhannad Saif El-Din',
#  'Bechara Abou Rejalie',
#  'Charley Bélanger',
#  'Greg Mannino',
#  'Al Loftes',
#  'Fernando Richeri',
#  'Jørgen Gabrielsen',
#  'Hennadiy Krasylnykov',
#  'Byron Wells',
#  'Fedor Weinschenk',
#  'Lucien Lésna',
#  'Harry Passmore',
#  'Mereg Mangascia',
#  'Leon Bebler',
#  'José Hernández',
#  'Sayed Al-Asibi',
#  'J. Tuzolto',
#  'Peggy Butler',
#  'Archibald Graham',
#  'Karel Lomecký',
#  'Andrey Bogdanovich',
#  'Reidar Raaen',
#  'Nam-Gyun Jeong',
#  'Rich Weiss',
#  'Willem van der Steen',
#  'Kostas Tsiklitiras',
#  'Paul Neukomm',
#  'Hanni Rehborn',
#  'Åse Idland',
#  'Omar Moussa',
#  'Yong-Hee Choi',
#  'Lewis Tewanima',
#  'George Marshall',
#  'Frits Bruseker',
#  'George Stapf',
#  'John Kidley',
#  'Alex Ireland',
#  'Carlos Serrano',
#  'Haluk Kakış',
#  'Grigory Voronkov',
#  'Léon Tétart',
#  '- Hébert',
#  'Yeong-Eun Sin',
#  'Norberto Cabrera',
#  'Tuomas Grönman',
#  'John Nuttall',
#  'V. Diju',
#  'Feofan Lebedev',
#  'Maurice Vignerot',
#  'Lylian Lecomte-Guyonneau',
#  'Marcel Dupraz',
#  'Jean Depassio',
#  'Ernie Roe',
#  'Stanisław Wilczyński',
#  'Gustav Tiefenthaler',
#  'Axel Persson',
#  'Américo Cattaruzza',
#  'Stefán Sörensson',
#  'Eleanor Goss',
#  'Anna Breuer',
#  'Yelena Ilyina',
#  'Omari Abdallah',
#  'Guy Granet',
#  'Karola Schustereder',
#  'Nabil Chouéry',
#  'Matthew Steytler',
#  'Ted White',
#  'Kittipon Kittikul',
#  'Natale Rea',
#  'Guy Hernandez',
#  'Bjørn Dyrdahl',
#  'Bob Likins',
#  'V. Khatzis',
#  'Pyotr Sedov',
#  'István Raggambi',
#  'Orlando Chaves',
#  'Édouard Taylor',
#  'Michel Rozan',
#  'Petro Koshelenko',
#  'Nicanor Villarreal',
#  'Grant Butcher',
#  'Aleksandr Schultz',
#  'André Blusset',
#  'Lincoln Johnson',
#  'Ösökhbayar Gelegjamtsyn',
#  'Tadeusz Starzyński-Starybrat',
#  'Kiều Oanh Nguyễn',
#  'Alex Wilson',
#  'J. M. Stuitl',
#  'Ölzii-Orshikh Jamsrangiin',
#  'Hyeong-Jun Ju',
#  'Charlie Tucker',
#  'Ingrid Lauridsen',
#  'Zambia Melakhroinou',
#  'Bill Knight',
#  'Alf Shawyer',
#  'José de Amézola',
#  'José María de Palleja',
#  'Larry Cummins',
#  'Jae-Seong Jeong',
#  'Maxie McCullagh',
#  'Andriy Hovorov',
#  'Friedrich Karl, Prince von Preußen',
#  'Lotfi Joudi',
#  'Mohammad Taj',
#  'Willibrordus Pouw',
#  'Murodzhon Khalmuratov',
#  'Théo Kueny',
#  'Dimitrios Konstantinidis',
#  'Karl Lampelmayer',
#  'Imre Elek',
#  'Singchow Chang',
#  'Sofiane Ben Letaief',
#  'Christiaan van Velzen',
#  'Hilda Wallis',
#  'Jack Keenan',
#  'Nassreddin El-Agely',
#  'Aleksandr Akhyun',
#  'Sergei Mureico',
#  'Bjørn Einar Romøren',
#  'Walter White',
#  'Aukusti Sihvola',
#  'Hussam El-Badrawi',
#  '- Sunarto',
#  'Yeong-Chang Go',
#  'Kostiantyn Miliaiev',
#  'C. H. Smith',
#  'László Lichteneckert',
#  'Jock Miller',
#  'Mariya Grozdeva',
#  'Roman Yeryomin',
#  'Yong-I Park',
#  'Leon Pyrgos',
#  'Aleksey Kuznetsov',
#  'Gil-Ok Jeong',
#  'Charles Deckert',
#  'Dezső Wein',
#  'Jørgen Jensen',
#  'Valentina Grigoryeva',
#  'Cecil Bissett',
#  'Fernand Rapin',
#  'Jean Psiakis',
#  '- Mia Audina',
#  'Aleksandra Gerasimenya',
#  'P. V. Sindhu',
#  'Dagvadorj Tserendorjiin',
#  'Marilyn Corson',
#  'Sergey Kudrevich',
#  'Mihai Bîră, Sr.',
#  'R. Uri',
#  'Wally Rivers',
#  'Fabrizio Nieva',
#  'Jimmy Davies',
#  'Alex Duncan',
#  'Håkan Nyblom',
#  "Ana T'at'ishvili",
#  'Georgy Fyodorov',
#  'Oscar Pérez',
#  'Tom Longboat',
#  'Li Xu',
#  'Ruedi Mangisch',
#  'Bakhrom Mendibayev',
#  'Fritz von Oesterley',
#  'Kálmán Becske',
#  'B. Zapletal',
#  'Aleksey Selikhov',
#  'Lew Rush',
#  'Vadim Shikarev',
#  'Jianqiang Chen',
#  'John Kennedy',
#  'Anatoly Vedyakov',
#  'Brynja Þorsteinsdóttir',
#  'Christy McLoughlin',
#  'John Purcell',
#  'Louisa Robert',
#  'Dinara Alimbekova',
#  'Alexandre Clergue',
#  'Robert Rey',
#  'Ab Oord',
#  'Amanda Dodd',
#  'Mikhail Pryakin',
#  'Aleksey Tsvetkov',
#  'Ovaness Meguerdonian',
#  'Vichai Limcharoen',
#  'Khamis Al-Subhi',
#  'Alison Owen-Spencer',
#  'Maksim Alyoshin',
#  'Natalia Nasaridze-Çakir',
#  'Jacques Sautereau',
#  'Deok-Ha Yun',
#  'Fernand Saivé',
#  'A. Grigoriadis',
#  'Rudie Lubbers',
#  'José Nozari',
#  'Andrea Kékesy',
#  'Albert Bourcier',
#  'François Denis de Rivoyre',
#  'Libuše Veselá',
#  'Ho-Jun Li',
#  'Edwin Vásquez',
#  'Barb Olmsted',
#  'John Woodcock',
#  'Þorsteinn Leifsson',
#  'C. Hamel',
#  'Yelena Besova',
#  'Nataliya Korostelyova',
#  'Naji Keyrouz',
#  'Franz Donth',
#  'John Hartranft',
#  'Jesus VILLAFANE MARQUINA',
#  'Maria Piątkowska-Chojnacka-Ilwicka',
#  'Changte Lalremsaga',
#  'August Elmik',
#  'Miloslava Tumová-Zahorska',
#  'Mbolatiana Ramanisa',
#  'Oidov Zevegiin',
#  'Abdi Gulet',
#  'František Stetina',
#  'Dong-U Gang',
#  'Lou Laurie',
#  'Marianna Némethová-Krajčírová',
#  'Jackie Callura',
#  'Dmitry Sinitsyn',
#  '- Juliana',
#  'Gizelle Miskey',
#  'Craig Ward',
#  'Sansarbileg Boldyn',
#  'Rodolfo Redaelli',
#  'Jacques Cariou',
#  'Verner Magnusson',
#  'Hanno Ströher',
#  'Iryna Kostiuchenkova',
#  'Sərdar Həsənov',
#  'Burhan Bozkurt',
#  'Carlomagno Meneses',
#  'Siegfried Haberl',
#  'Erzsébet Bartos-Heldt',
#  'Nirmala Sheoran',
#  'Antonius Budi Ariantho',
#  'Ihor Della-Rossa',
#  'Geeta Zutshi',
#  'Mac Joachim',
#  'Amedée Piguet',
#  'Harry Young',
#  'Ernest Meyer',
#  'Jack Cropp',
#  'Surapong Sripirom',
#  'Berger Torrissen',
#  'Trung Lê Trung',
#  'José Luis Torres',
#  'Joaquín Miquel',
#  'Murad Umakhanov',
#  '- Ollivier',
#  'Serhiy Novikov',
#  'Hans Fraberger',
#  'Seong-Il Song',
#  'Elçin Mehdi İsmayılov',
#  'Oleksandr Tkachenko',
#  'Rachid El-Haddak',
#  'Colombo Zevola',
#  'Sergey Kochetkov',
#  'Won-Gwon Kim',
#  'Miroslav Metzner-Fritz',
#  'Dariimaa Natjavyn',
#  'Khishigbaatar Gombyn',
#  'Bashay Feleke',
#  'Jan Mildev',
#  'Abrar Osman Adem',
#  'Gadissie Edato',
#  'Gino Cantone',
#  'Ingenuino Dallagio',
#  'Levan Gureshidze',
#  'Bill Stevenson',
#  'Mykola Vasyliev',
#  'Sarjarao Suryavanshi',
#  'Jesús Oyarbide',
#  'Sergio Martínez',
#  'Adolf Rieger',
#  'Maksim Iglinsky',
#  'Josef Bechyně',
#  'Tjeerd Pasma',
#  'Amarjargal Tserendorjiin',
#  '- Fábio',
#  'Guram Biganishvili',
#  'Vladimir Shilykovsky',
#  'Jovan Đolić',
#  'Ayodele Peters',
#  'A. Luña Soria',
#  'Sven Emil Lundgren',
#  'Maas van der Feen',
#  'Léon Gingembre',
#  'Pam Kilborn-Ryan',
#  'Hilde Walterová',
#  'Jean Roldes',
#  'Robert Thach',
#  'José Llobera',
#  'Helmer Måhl',
#  'Miroslav Málek',
#  'Sun-Cheon Gwon',
#  'Israel Wijnschenk',
#  'Gaston Koëger',
#  'Georgi Markov',
#  'Jaap Eden',
#  'Juozas Vinča',
#  'Thor-Øistein Endsjø',
#  'Eduardo Arrillaga',
#  'Olha Teslenko',
#  'Linar Salimullin',
#  'Jock Dalrymple',
#  'Jindřich Lepiere',
#  'José Andía',
#  'Oleksiy Korobeinikov',
#  'Eduardo Florez',
#  'Henri Stuckmann',
#  '- Rouchy',
#  'Cheong-Tae Kim',
#  'Edouard Léonard',
#  'Snezhana Yurukova',
#  '- Bouchon',
#  'José Viccario',
#  'Ord Fink',
#  'Davit Khakhaleishvili',
#  'Farid Salman Makhdi',
#  'Rudolf Kus',
#  'Phil Edwards',
#  'W. Stewart',
#  'Ag. Diamantopoulos',
#  'Seong-Ja Sin',
#  'Jenny Thompson',
#  'Ken Bartholomew',
#  'Milka Akinyi',
#  'Jong-Moon Byun',
#  'Oksana Skliarenko',
#  'Mohammed Alghafri',
#  'Dmitry Sakunenko',
#  'Fred Gilmore',
#  'Ali Reza Azari',
#  'Joseph Leresae',
#  'Soňa Vašíčková',
#  'Fabián Velasco',
#  'Per Erik Løkken',
#  'Harry Parker',
#  'Muhammad Sadiq',
#  'Béla Szabó',
#  'Otto Pohla',
#  'Oksana Menkova',
#  'Mario Giuria',
#  'Chang-Nam Pyeon',
#  'Rolands Upatnieks',
#  'Ted Boronovskis',
#  'Nils Karlsson',
#  'Charles Palmer-Tomkinson',
#  'Joseph Jessop',
#  'Magdaleno Cano',
#  '- Sandra',
#  'Aleksandr Alenitsyn',
#  'Václav Balšán',
#  'Viktor Baranov',
#  'Jerzy Dzięcioł',
#  'Jin-Seon Yu',
#  'Konstantinos Kariotis',
#  'Ed Don George',
#  'Mohammad Malik Arshad',
#  'Albert Martin',
#  'Nabil Abdul Tahlak',
#  'I. Markou',
#  'Georgi Danchev',
#  'Hassan Al-Absi',
#  'Antonie de Gee',
#  'Yvonne von Kauffungen',
#  'Kurt Einsiedel',
#  'Marius Etcheparré',
#  'Miltiadis Iatrou',
#  'Divya Tewar',
#  'Josef Přidal',
#  'Will Hildreth',
#  'Barbra Higgins',
#  'Hiếu Hiền Ðặng',
#  'Aladár Háberl',
#  'Mohammed Yaseen Mohammed',
#  'A. Kadar',
#  'Ernie Smith',
#  'Jørgen Barth-Jørgensen',
#  'Choon-Za Kim',
#  'Lajos Csejthey',
#  'Luis Torralva',
#  'Bill Kirschbaum',
#  'Yevgeny Yevsyukov',
#  'Ruth Langer',
#  'Dora Schönemann',
#  'Artur Akoyev',
#  'Lennart Lind',
#  'Rainer Bergmann',
#  'Georges Leuillieux',
#  'Willie Toweel',
#  'Petre Pavel',
#  'José Manuel Soto',
#  'Yeong-Seo Gang',
#  'Conrad Hauge',
#  'Bong-Su Kim',
#  'Abby Hoffman',
#  'Sara Teitelbaum',
#  'Wim Esajas',
#  'Martin Brustmann',
#  'Dorothy Franey',
#  'Cuiting Chen',
#  'Frank Carter',
#  'Wally Beavers',
#  'Ivaylo Sharankov',
#  'Jaap Sjouwerman',
#  'Sol. Xenopoulos',
#  'Alex Hurd',
#  'Georges Bordier',
#  'Dölgöön Batsaikhanyn',
#  'Tim Boyd',
#  'Szabolcs Izsák',
#  'Domingo Torralva',
#  'Rogelio Weatherbee',
#  'Katalin Pál-Ribáry',
#  'Osman El-Sayed',
#  'Émile Michelet',
#  'Antonio Mariscal',
#  '- Vanitakis',
#  'Yury Sharkov',
#  'Lazaros Kekhagias',
#  'Bela Imre',
#  'Carol Borges-Mendelblatt',
#  'Nilo Marques Medeiros',
#  'Alfredo Gaona',
#  'Eun-Seok O',
#  'Steve Mwema',
#  'Victor Pierre Eggman',
#  'Khuwaled Al-Harthi',
#  'Arthur Bartlett',
#  'Émile Fréteur',
#  'Alessandro Messina',
#  'Ganga Bahadur Thapa',
#  'Helge Breckwoldt',
#  'Nataliya Khoronenko-Mikhnevich',
#  'Andrey Rybakov',
#  'Abdul Latif Rozaihan',
#  'Jeong-Yeon Jeong',
#  'Yevheniya Filanenko',
#  'Om Prasad Pun',
#  'Louis Lallue',
#  'Adolphe Dumont',
#  'James Galli',
#  "Joseph M'Bouroukounda",
#  'Valentin Dzhonev',
#  'Sharon Hedrick',
#  'Dmitry Bankovsky',
#  'Arnaud, Marquis de Castelbajac',
#  'J. Schmöllerl',
#  'Leo Ravilo',
#  'Sid Jensen',
#  'C. Chun Wang',
#  'Gian-Ferdinando Tommaselli',
#  'Nandinzayaa Gankhuyagiin',
#  'F. Negri',
#  'Antoine Longoudé',
#  'Johannes Heuckelbach',
#  'Olesia Zaitseva',
#  'Ibrahim Al-Idokht',
#  'Hui-Jin Jang',
#  'Yevgeny Zykov',
#  'Judy Canty',
#  'Nadine Rolland',
#  'Roger Delabassee',
#  'Jin-Seop Jo',
#  'Russell Brander',
#  'Emily Woodruff',
#  'Jim Murphy',
#  '- Gille',
#  'Yelena Matyushenko',
#  'Mario Portolongo',
#  'Toğrul Əsgərov',
#  'Henk Hemsing',
#  'Dorothea Dickinson',
#  'Mikuláš Kucsera',
#  'Mi-Gyeong Lee',
#  'Alfred Nilsen',
#  'Cootje van Kampen-Tonneman',
#  'Frederick Toms',
#  'Yury Chervanyov',
#  'Dmitry Chernyshov',
#  'Fred Lord',
#  'Augusto Bonadio',
#  'Mohinder Singh',
#  'Aladár Bitskey',
#  'Léon Coeckelberg',
#  'José Ricardo Rodrigues',
#  'Georges Bernaert',
#  'Jouko Kuha',
#  'Enkhbaatar Byambajavyn',
#  'Reinaldo Paseiro',
#  'Fatiha Ouali',
#  'Sue Longden',
#  'Kbary Salim',
#  'Satpal Singh',
#  'Aleksey Kolesov',
#  '- Favier',
#  'Gennady Garbuzov',
#  'Harry Dunn',
#  'Dave Hazewinkel',
#  'Wasif Ibrahim',
#  'Pyotr Asayonok',
#  'Aleksey Ivanov',
#  'George Kearns',
#  'Nazlati Mohamed',
#  'Zephaniah Ncube',
#  'Mikhail Klecherov',
#  'Ikhlef Ahmed Hadj Allah',
#  'Aleksandr Alekseyev',
#  'Hui-Sik Im',
#  'Edvard Antonijevič',
#  'Pradip Bode',
#  '- De Poorten',
#  'Prince Faisal Al-Shalan',
#  'Svitlana Konstantynova',
#  '- Van Schauwenbroeck',
#  'Altantsetseg Byambajavyn',
#  'Gilbert Van Cleve',
#  'Yusuf Dalgınlı',
#  'Janez Porenta',
#  '- Debailly',
#  "Pierre Dufour d'Astafort",
#  'Bujie Duo',
#  'John Odde',
#  'Nanak Chand Thakur',
#  'Yuliya Milko-Chernomorets',
#  'Viktor Maygurov',
#  'Semyon Kolobayev',
#  'Pyotro Sarafyniuk',
#  'Enrique Inostroza',
#  'Isidor Bieri',
#  'John Burra',
#  'Karl Vilmundarson',
#  'Émile Rettig',
#  'Hanna Karnaushenko',
#  'Lal Chand',
#  'José Luis Villanueva',
#  'Harry Houghton',
#  'Üner Teoman',
#  'Murray Gitlitz',
#  'Ray Magee',
#  'Richard von Arx',
#  'Antal Kánya',
#  'Joseph Castiglioni',
#  'Jolán Mertin',
#  'Alexander Spengler',
#  'Pierre Tolar',
#  'Rosen Vasilev',
#  'Piet Belmer',
#  'Juan Torruella, Jr.',
#  'Rūdolfs Ronis',
#  'Abdul Majeed',
#  'Aleksey Shibko',
#  'Aleksandrs Prokopčuks',
#  'Ahmed Lutfi Shihad',
#  'L. Cabrolié',
#  'Clovis Cambon',
#  'Ibrahim El-Dessouki',
#  'Tijini Ben Kassou',
#  'Ellen Babington',
#  'Arthur Olsen',
#  'Georgios Valakakis',
#  'Maxime Landin',
#  'Sara Blengsli Kværnø',
#  'Michel Frédérick',
#  'Eugène Grisar',
#  'James McKenzie',
#  'Khoilogdorj Megdiin',
#  'Al. Blachère',
#  'Vivian King',
#  'Khadour Adnan',
#  'Art Smoke',
#  'Sandór Veres',
#  'Mohamed Kedir',
#  'Nat Moore',
#  'Aleksandr Bersanov',
#  'Kiril Georgiev',
#  'Dashjamts Dovdongiin',
#  'Olga Kardopoltseva',
#  'Charles Brécy',
#  'G. E. Stevens',
#  '- Koubi',
#  'Anatoly Petrov',
#  'Nikola Vučević',
#  'Muhammad Ramzan',
#  '- Taube',
#  'Ricardo Pueyo',
#  'Yu-Ri Gwon',
#  'Pierre Hernandez',
#  'Camiel Vandevelde',
#  'Arthur Chase',
#  'Eddie Farrell',
#  'Wilhelm Hansen',
#  'Vera Kummerfeld',
#  'Vladimír Vávra',
#  'Vangelis Kouvelis',
#  'Markus Maier',
#  'George Fisher',
#  'Vitaly Andreyev',
#  'Xavier De Beukelaer',
#  'Bengt Wallin',
#  'Hugo Lilliér',
#  'Mohamed Abu Sobea',
#  'Sidney Ramsden',
#  'Mozes Jacobs',
#  'Marwan Suhail Aboud',
#  'Ivan Cherezov',
#  'Paul Texier',
#  'Carlos Orellana',
#  'Danny McDonald',
#  'Tsend-Ayuush Namkhain',
#  'Anny Cody-Morris',
#  'Johannes Pedersen',
#  'Harvey Lacelle',
#  'Alex Oakley',
#  'István Zsadanyi',
#  'Bakhyt Odnoin',
#  'Oscar Simón',
#  'Octave Alleaume',
#  '- Dufau',
#  'Juan Escutia',
#  'Ihor Tselovalnykov',
#  'A. Gonzani',
#  'Becky Smith',
#  'Aimé-Joseph Escudie',
#  'Bong-Sik Pak',
#  'Alberto Ramos',
#  'Vanessa Kolodinskaya',
#  'Lena Valaoritou',
#  'Marianna Nagy',
#  'Nikolay Zuyev',
#  'Victor Macha',
#  'Yinjiya Sai',
#  'Marcel Quilbeuf',
#  'Felicia Țilea-Moldovan',
#  'Joseph Welzenbacher',
#  'Ahmed Al-Ahmed',
#  'Alisa Xalıyeva',
#  'Robert Jolly',
#  'Arvid Hoflund',
#  'K. Meraklis',
#  'Jozef Herda',
#  'Yevgeny Zhernosek',
#  'Ray Bateman, Jr.',
#  'Filip Löwendahl',
#  'Jamie Pagendam',
#  'Frederico Burnay',
#  'Jackie Galloway',
#  'José Macedo',
#  'Byambasüren Nyamtserengiin',
#  'Gyu-Cheol Jang',
#  'Peter Young',
#  'Khasan Isaev',
#  'Andrew Young',
#  'Da-Wun Jeong',
#  'Angelo Vaccari',
#  'Bill Kennedy',
#  'Jae-Gi Jo',
#  'Abdullah Al-Usaimi',
#  'Viktoriya Troitskaya-Taranina',
#  'Nadezhda Radovitskaya',
#  'Anastasiya Novikova',
#  'Luigi Faure',
#  'Yong-Cheol Jo',
#  'Tom Linton',
#  'Sergey Sharikov',
#  'Pietro Bignamini',
#  'Tadeusz Gorzechowski',
#  'Anicet Sambo',
#  'Vitaliy Martsiv',
#  'Pərviz Bağırov',
#  'Yelena Matoshko',
#  'Ruth Hauser',
#  'Edmund Aspinall',
#  'Mihály Váradi',
#  'Şərif Şərifov',
#  'Lars Erik Tirén',
#  'Sergey Chepikov',
#  'Masini Situ-Kumbanga',
#  'Harry Kiener',
#  'Aldo Cigheri',
#  'Seung-Rip O',
#  'Stelios Benardis',
#  'Pyotr Zayev',
#  'Ryszard Błażyca',
#  'Hans Schwerzmann',
#  'Sayed Farhad',
#  'In-Won Jang',
#  'Nikolaos Kouloumberdas',
#  '- Geor',
#  'Giulan Liu',
#  'James Hill',
#  'Tetiana Lysenko',
#  'Al Cantello',
#  'Gerasimos Anagnostou',
#  'Erling Seeberg',
#  'Olga Khudenko',
#  'Mário Maurity',
#  'Freddie Tomlins',
#  'Hussain Mohamed Hassan',
#  'Magomed Nurutdinov',
#  'Gonzalo Alvarado',
#  'Yury Shlyapin',
#  'Oyuunbold Dugarsürengiin',
#  'Nikolay Novikov',
#  'Antero Viljaharju',
#  'G. Guillotin',
#  'Erich Spörer',
#  'Aleksandr Panzhinsky',
#  'Nikolay Shubyonok',
#  'Rostyslav Zaulychniy',
#  'Harry Gissing',
#  'Ron Foubister',
#  'Perry Martter',
#  'Cavid Tağıyev',
#  'Norayr Nurikyan',
#  'Tuyana Dashidorzhiyeva',
#  'Krisjānis Kundziņš',
#  'Gerry Collins',
#  'Léon Roller',
#  'Mikhail Krasilov',
#  'Joseph Ducrot',
#  ...}

# %%
# oula, il y a des différences... on va essayer de corriger ça
missing_athletes_df = cleaned_results[cleaned_results['athlete_full_name'].isin(missing_athletes)][['athlete_full_name', 'athlete_url']]
# supprimer les doublons
missing_athletes_df.drop_duplicates(inplace=True)

# %%
def get_games_participations(athlete_full_name: str) -> int:
    '''
    Retourne le nombre de participations à des JO
    déterminé par le nombre de valeurs uniques de la colonne 'slug_game'
    '''
    return len(cleaned_results[cleaned_results['athlete_full_name'] == athlete_full_name]['slug_game'].unique())

# %%
missing_athletes_df['games_participations'] = missing_athletes_df['athlete_full_name'].apply(get_games_participations)

# %%
# on détermine les premiers jeux olympiques de chaque athlète en fonction de la date parsée dans le slug_game
def get_first_games(athlete_full_name: str) -> str:
    '''
    Retourne les premiers jeux olympiques
    '''
    all_athlete_games = cleaned_results[cleaned_results['athlete_full_name'] == athlete_full_name]['slug_game']
    all_athlete_games = all_athlete_games.drop_duplicates()

    if(all_athlete_games.empty):
        return None
    
    if(all_athlete_games.shape[0] == 1):
        return all_athlete_games.iloc[0]
    
    # sinon on récupère les 4 derniers caractères du slug (année des JO) et on renvoi le slug dont l'année est la plus petite
    return all_athlete_games[all_athlete_games.str[-4:].astype(int).idxmin()]

# %%
missing_athletes_df['first_game'] = missing_athletes_df['athlete_full_name'].apply(get_first_games)

# %%
# on rempli les colonnes athlete_year_birth	athlete_medals	bio avec des valeurs nulles
missing_athletes_df['athlete_year_birth'] = 0
missing_athletes_df['athlete_medals'] = None
missing_athletes_df['bio'] = None

# %%
missing_athletes_df.head()
# Out:
#                 athlete_full_name  \
# 10                            NaN
# 1920  Alexandru Stefan STEFANESCU
# 2692                Raimo VIGANTS
# 2698             Thibaut DE MARRE
# 3142                 CIRENZHANDUI
#
#                                             athlete_url  games_participations  \
# 10                                                  NaN                     0
# 1920  https://olympics.com/en/athletes/alexandru-ste...                     1
# 2692     https://olympics.com/en/athletes/raimo-vigants                     1
# 2698  https://olympics.com/en/athletes/thibaut-de-marre                     1
# 3142      https://olympics.com/en/athletes/cirenzhandui                     1
#
#         first_game  athlete_year_birth athlete_medals   bio
# 10            None                   0           None  None
# 1920  beijing-2022                   0           None  None
# 2692  beijing-2022                   0           None  None
# 2698  beijing-2022                   0           None  None
# 3142  beijing-2022                   0           None  None

# %%
# on merge les deux dataframes
athletes = pd.concat([athletes, missing_athletes_df], ignore_index=True)

# %%
athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83875 entries, 0 to 83874
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   athlete_url           75929 non-null  object
#  1   athlete_full_name     83874 non-null  object
#  2   games_participations  83875 non-null  int64
#  3   first_game            83852 non-null  object
#  4   athlete_year_birth    83875 non-null  int64
#  5   athlete_medals        15352 non-null  object
#  6   bio                   22842 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 4.5+ MB

# %%
# exportation
athletes.to_csv('exports/olympic_athletes_cleaned.csv', index=False, encoding='utf-8')

# %%
# TODO: déterminer la matrice des pays des athlètes

# %% [markdown]
# ### Pays
#
# On exporte les données dédupliquées et nettoyées des pays pour faciliter l'insertion en base de données

# %%
countries = cleaned_results[['country_name', 'country_code', 'country_3_letter_code']]
countries.head()
# Out:
#   country_name country_code country_3_letter_code
# 0        Italy           IT                   ITA
# 0        Italy           IT                   ITA
# 1       Norway           NO                   NOR
# 1       Norway           NO                   NOR
# 2       Sweden           SE                   SWE

# %%
# suppression des doublons
countries = countries.drop_duplicates()

# %%
# vérification des valeurs nulles
countries.isnull().sum()
# Out:
# country_name              0
# country_code             22
# country_3_letter_code     0
# dtype: int64

# %%
# on vérifie l'unicité des codes pays pour assurer l'intégrité des données
countries['country_3_letter_code'].duplicated().sum()
# Out:
# 9

# %%
# voir les valeurs dupliquées
countries[countries['country_3_letter_code'].duplicated()]
# Out:
#                                     country_name country_code  \
# 10366                                  Singapore          NaN
# 10686                                     Norway          NaN
# 12976  The Former Yugoslav Republic of Macedonia           MK
# 14637                                Ivory Coast           CI
# 18087                          US Virgin Islands           VI
# 21592                     British Virgin Islands           VG
# 26082                                  Swaziland           SZ
# 67250                                    Nigeria          NaN
# 89264                                     Zambia          NaN
#
#       country_3_letter_code
# 10366                   SGP
# 10686                   NOR
# 12976                   MKD
# 14637                   CIV
# 18087                   ISV
# 21592                   IVB
# 26082                   SWZ
# 67250                   NGR
# 89264                   ZAM

# %%
# on garde la ligne avec la valeur non nulle de country_code
countries = countries.sort_values('country_code').drop_duplicates('country_3_letter_code', keep='first')

# %%
# exportation
countries.to_csv('exports/olympic_countries.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Discipline
#
# On exporte les données dédupliquées et nettoyées des disciplines pour faciliter l'insertion en base de données

# %%
disciplines = cleaned_results[['discipline_title']]
disciplines.head()
# Out:
#   discipline_title
# 0          Curling
# 0          Curling
# 1          Curling
# 1          Curling
# 2          Curling

# %%
# supprimer les doublons
disciplines = disciplines.drop_duplicates()

# %%
# vérification des valeurs nulles
disciplines.isnull().sum()
# Out:
# discipline_title    0
# dtype: int64

# %%
# exportation
disciplines.to_csv('exports/olympic_disciplines.csv', index=False, encoding='utf-8')

# %% [markdown]
# ###  Jeux

# %%
hosts = pd.read_xml('imports/olympic_hosts.xml', encoding='utf-8')
hosts.set_index('index', inplace=True)
hosts.head()
# Out:
#               game_slug         game_end_date       game_start_date  \
# index
# 0          beijing-2022  2022-02-20T12:00:00Z  2022-02-04T15:00:00Z
# 1            tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z
# 2      pyeongchang-2018  2018-02-25T08:00:00Z  2018-02-08T23:00:00Z
# 3              rio-2016  2016-08-21T21:00:00Z  2016-08-05T12:00:00Z
# 4            sochi-2014  2014-02-23T16:00:00Z  2014-02-07T04:00:00Z
#
#             game_location         game_name game_season  game_year
# index
# 0                   China      Beijing 2022      Winter       2022
# 1                   Japan        Tokyo 2020      Summer       2020
# 2       Republic of Korea  PyeongChang 2018      Winter       2018
# 3                  Brazil          Rio 2016      Summer       2016
# 4      Russian Federation        Sochi 2014      Winter       2014

# %%
hosts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53 entries, 0 to 52
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   game_slug        53 non-null     object
#  1   game_end_date    53 non-null     object
#  2   game_start_date  53 non-null     object
#  3   game_location    53 non-null     object
#  4   game_name        53 non-null     object
#  5   game_season      53 non-null     object
#  6   game_year        53 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 3.3+ KB

# %%
# vérifier les valeurs dupliquées
hosts.duplicated().sum()
# Out:
# 0

# %%
# vérifier les valeurs nulles
hosts.isnull().sum()
# Out:
# game_slug          0
# game_end_date      0
# game_start_date    0
# game_location      0
# game_name          0
# game_season        0
# game_year          0
# dtype: int64

# %%
# vérifier si on n'a que deux saisons
hosts['game_season'].unique()
# Out:
# array(['Winter', 'Summer'], dtype=object)

# %%
# on vérifie si les données des résultats sont cohérentes avec les données des hôtes
results_hosts = cleaned_results['slug_game'].unique()
hosts_games = hosts['game_slug'].unique()

# différences
missing_hosts = set(results_hosts) - set(hosts_games)
missing_hosts
# Out:
# set()

# %%
# on projette d'utiliser la table des pays comme clé étrangère pour la colonne game_location
# on vérifie si les pays sont bien renseignés
countrie_names = countries['country_name'].unique()
hosts_countries = hosts['game_location'].unique()

# différences
missing_countries = set(hosts_countries) - set(countrie_names)
missing_countries
# Out:
# {'Australia, Sweden', 'China', 'USSR', 'United States'}

# %%
# heureusement il n'y a pas beaucoup de différence, on les règle à la main
hosts = hosts.replace({ 'game_location': { 
    'United States': 'United States of America',
    'Australia, Sweden': 'Australia',
    'USSR': 'Soviet Union',
    'China': 'People\'s Republic of China' }})

# %%
# on vérifie si le netttoyage a bien été effectué
hosts_countries = hosts['game_location'].unique()
missing_countries = set(hosts_countries) - set(countrie_names)
missing_countries
# Out:
# set()

# %%
# exportation
hosts.to_csv('exports/olympic_hosts_cleaned.csv', encoding='utf-8')

# %% [markdown]
# ### Evenements

# %%
events = cleaned_results[['event_title', 'discipline_title', 'slug_game']]
events.head()
# Out:
#      event_title discipline_title     slug_game
# 0  Mixed Doubles          Curling  beijing-2022
# 0  Mixed Doubles          Curling  beijing-2022
# 1  Mixed Doubles          Curling  beijing-2022
# 1  Mixed Doubles          Curling  beijing-2022
# 2  Mixed Doubles          Curling  beijing-2022

# %%
# supprimer les doublons
events = events.drop_duplicates()

# %%
# vérifier des valeurs nulles
events.isnull().sum()
# Out:
# event_title         0
# discipline_title    0
# slug_game           0
# dtype: int64

# %%
def get_event_gender(title: str) -> str:
    '''
    Détermine le genre de l'événement en fonction du titre
    '''
    title = title.lower()
    if "women" in title or "ladi" in title:
        return 'Women'
    if "men" in title:
        return 'Men'
    if "mixed" in title:
        return 'Mixed'
    return 'Men'

# %%
# ajout de la colonne event_gender
events['event_gender'] = events.apply(lambda x: get_event_gender(x['event_title']), axis=1)

# %%
# exportation
events.to_csv('exports/olympic_events.csv', index=False, encoding='utf-8')
